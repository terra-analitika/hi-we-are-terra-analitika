# %% [markdown]
# <a href="https://colab.research.google.com/github/terra-analitika/hi-we-are-terra-analitika/blob/master/intro_to_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Run your first code with Jupyter Notebook**
#
# by: Yohanes Nuwara

# %% [markdown]
# If you are new to **Jupyter Python notebook**, you run one cell (clicking the arrow) in the left of the code, then the result appears. Go run every cell, but **keep in mind** that you have to do it one by one & step by step from the very 1st cell. Don't jump. Because the next cell needs the code from previous cell.
#
# ![alt text](https://pydata.org/wp-content/uploads/2016/07/jupyter-logo-300.png)

# %% [markdown]
# Because you are in `Google Colab`, you need to mount your Drive. Why? You will access our shared drive in Google Drive called `colab-terra`. There, you will retrieve the notebooks, run in your Google Colab, edit the codes, store it back to the drive, and whatever you want with the drive.
#
# When you run, you will be given a link and a blank space. Click the link, then verify your gmail account, until you are given another link. Copy the link to the blank space, click enter. Now ready to go.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Just like every programming language, start with "hello world"

# %%
print("hello world")

# %% [markdown]
# You need to import the basic libraries.

# %%
import numpy as np
import matplotlib as mpl
import pandas as pd
import scipy as spy

# %% [markdown]
# If you want to build powerful data science and machine learning programs, you may import these libraries.

# %%
import sklearn as skl
import keras as k
# !pip install tensorflow
import tensorflow as tf

# %% [markdown]
# # How to Import Function
#
# When you run a code, sometimes you need to make a `function` or import it. `Functions` are added in `colab-terra` Drive. First we have to import it first, call from the Drive.

# %%
import sys
sys.path.append('/content/drive/My Drive/colab-terra/intro')

# %% [markdown]
# For example you want to take an average of sets of numbers (mean of numbers).
#
# ![alt text](http://www.ihatepsm.com/sites/default/files/blog/mean%20ungrouped%20data.png)

# %% [markdown]
# You make the function first in standard Python extension (`.py`), and then add to `colab-terra` drive. For instance, we have provided `mean.py` in the Drive. Import it.

# %%
import mean as m

# %% [markdown]
# For example a student has seven math exam grades 75, 86, 85, 67, 90, 68, 95. His average math grades are.

# %% [markdown]
# # Now is your turn!
#
# Go code yourself! You can practice coding everything here. These are 3 cool examples before you start.

# %% [markdown]
# # Example 1. Visualizing Economic Growth

# %%
import matplotlib.pyplot as plt

# Prepare Data (read data from github, paste the link)
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/economics.csv", parse_dates=['date']).head(100)
x = np.arange(df.shape[0])
y_returns = (df.psavert.diff().fillna(0)/df.psavert.shift(1)).fillna(0) * 100

# Plot
plt.figure(figsize=(16,10), dpi= 80)
plt.fill_between(x[1:], y_returns[1:], 0, where=y_returns[1:] >= 0, facecolor='green', interpolate=True, alpha=0.7)
plt.fill_between(x[1:], y_returns[1:], 0, where=y_returns[1:] <= 0, facecolor='red', interpolate=True, alpha=0.7)

# Annotate
plt.annotate('Peak \n1975', xy=(94.0, 21.0), xytext=(88.0, 28),
             bbox=dict(boxstyle='square', fc='firebrick'),
             arrowprops=dict(facecolor='steelblue', shrink=0.05), fontsize=15, color='white')


# Decorations
xtickvals = [str(m)[:3].upper()+"-"+str(y) for y,m in zip(df.date.dt.year, df.date.dt.month_name())]
plt.gca().set_xticks(x[::6])
plt.gca().set_xticklabels(xtickvals[::6], rotation=90, fontdict={'horizontalalignment': 'center', 'verticalalignment': 'center_baseline'})
plt.ylim(-35,35)
plt.xlim(1,100)
plt.title("Month Economics Return %", fontsize=22)
plt.ylabel('Monthly returns %')
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# # Example 2. Visualizing CT Scan

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
from matplotlib.path import Path
from matplotlib.patches import PathPatch

w, h = 512, 512

with cbook.get_sample_data('ct.raw.gz') as datafile:
    s = datafile.read()
A = np.frombuffer(s, np.uint16).astype(float).reshape((w, h))
A /= A.max()

fig, ax = plt.subplots()
extent = (0, 25, 0, 25)
im = ax.imshow(A, cmap=plt.cm.hot, origin='upper', extent=extent)

markers = [(15.9, 14.5), (16.8, 15)]
x, y = zip(*markers)
ax.plot(x, y, 'o')

ax.set_title('CT Scan of Your Head', size=30)
fig.set_size_inches(18.5, 10.5)

plt.show()

# %% [markdown]
# # Example 3. Visualizing Earth Map

# %% [markdown]
# You need to install `mpl_toolkits` library. Run this code first, and wait it finishes downloading. It takes quite long time, wait until it finishes. You will be asked to `Restart Runtime`. Click it.

# %%
# !apt-get install libgeos-3.5.0
# !apt-get install libgeos-dev
# !pip install https://github.com/matplotlib/basemap/archive/master.zip

# %% [markdown]
# And then run this. Wait until it is finished.

# %%
# !pip install pyproj==1.9.6

# %% [markdown]
# You are ready to import `mpl_toolkits` and make your cool map!

# %%
from mpl_toolkits.basemap import Basemap

import matplotlib.pyplot as plt
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution=None,lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
plt.figure(figsize=(20,10))
m.etopo()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # There are lots of interesting codes in the internet
#
# that you can practice here. Practice makes perfect!
